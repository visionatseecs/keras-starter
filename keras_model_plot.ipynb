# %% [markdown]
# #Plotting a model in keras <br>
# In this notebook we will see how to visualize our models in keras. <br>
#
# But before plotting the model in `keras`, let me show you how to draw a simple neural network using `graphviz` library in the below section:

# %% [markdown]
# #### Drawing a Neural Network graph using graphviz

# %% [markdown]
# Below, we have instantiated a Digraph instance and added nodes and edges. <br>
# `Digraph()` will create a directed graph in dot language. <br>
# `node()` function creates a node. It takes a name which is a unique identifier and label which is the label of that node. <br>
# `edges()` function will take a list of all edges.

# %%
from graphviz import Digraph

dot = Digraph(comment='MLP')
dot.node('A', 'input1')
dot.node('B', 'h11')
dot.node('C', 'h12')
dot.node('D', 'h21')
dot.node('E', 'h22')
dot.node('F', 'h23')
dot.node('G', 'output1')
dot.edges(['AB', 'AC', 'BD', 'BE', 'BF', 'CD', 'CE', 'CF', 'DG', 'EG', 'FG'])

# %%
# check the generated source code
print(dot.source)
# Out:
# // MLP
# digraph {
# 	A [label=input1]
# 	B [label=h11]
# 	C [label=h12]
# 	D [label=h21]
# 	E [label=h22]
# 	F [label=h23]
# 	G [label=output1]
# 	A -> B
# 	A -> C
# 	B -> D
# 	B -> E
# 	B -> F
# 	C -> D
# 	C -> E
# 	C -> F
# 	D -> G
# 	E -> G
# 	F -> G
# }

# %%
# view the graph
dot

# %%
# save the and render the source code
dot.render('simple_nn', format='png')
# Out:
# 'simple_nn.png'

# %% [markdown]
# #### Plot the above ANN in keras <br>
# Now we will learn how to plot models in keras. To plot the above NN in keras, let's first create the model using keras Sequential API.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(2, input_dim=1, activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **1) Plot using summary() function**
#
# The simple way to visualize a model is using `summary()` function of the model. It will show the layers as well as number of parameters at each layer. The number of parameters is calculated including the bias node as well.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 2)                 4
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 9
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 4
# ...
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **2) Plot using `plot_model() function`**
#
# The second method for viualizing the model is to plot it using `plot_model()` function of `vis_utils` library. This function converts a Keras model to dot format and saves to a file.

# %%
from keras.utils.vis_utils import plot_model

# %%
plot_model(model, to_file='model.png', show_shapes=True)

# %% [markdown]
# Visualizing the model has several benefits. We can confirm the layers' order, know the output shape of each layer and also the number of parameters at each layer. Therefore, it is recommended to visualize the model using any of the methods we discussed above.
